# %% [markdown]
# <h2>HW3.0.
# What is a merge sort? Where is it used in Hadoop?
# How is  a combiner function in the context of Hadoop?
# Give an example where it can be used and justify why it should be used in the context of this problem.
# What is the Hadoop shuffle?</h2>

# %% [markdown]
# <h2>HW3.1 Use Counters to do EDA (exploratory data analysis and to monitor progress)</h2>
# Counters are lightweight objects in Hadoop that allow you to keep track of system progress in both the map and reduce stages of processing. By default, Hadoop defines a number of standard counters in "groups"; these show up in the jobtracker webapp, giving you information such as "Map input records", "Map output records", etc.
#
# While processing information/data using MapReduce job, it is a challenge to monitor the progress of parallel threads running across nodes of distributed clusters. Moreover, it is also complicated to distinguish between the data that has been processed and the data which is yet to be processed. The MapReduce Framework offers a provision of user-defined Counters, which can be effectively utilized to monitor the progress of data across nodes of distributed clusters.
#
# Use the Consumer Complaints  Dataset provide here to complete this question:
#
#      https://www.dropbox.com/s/vbalm3yva2rr86m/Consumer_Complaints.csv?dl=0
#
# The consumer complaints dataset consists of diverse consumer complaints, which have been reported across the United States regarding various types of loans. The dataset consists of records of the form:
#
# Complaint ID,Product,Sub-product,Issue,Sub-issue,State,ZIP code,Submitted via,Date received,Date sent to company,Company,Company response,Timely response?,Consumer disputed?
#
# Here’s is the first few lines of the  of the Consumer Complaints  Dataset:
#
# Complaint ID,Product,Sub-product,Issue,Sub-issue,State,ZIP code,Submitted via,Date received,Date sent to company,Company,Company response,Timely response?,Consumer disputed?
# 1114245,Debt collection,Medical,Disclosure verification of debt,Not given enough info to verify debt,FL,32219,Web,11/13/2014,11/13/2014,"Choice Recovery, Inc.",Closed with explanation,Yes,
# 1114488,Debt collection,Medical,Disclosure verification of debt,Right to dispute notice not received,TX,75006,Web,11/13/2014,11/13/2014,"Expert Global Solutions, Inc.",In progress,Yes,
# 1114255,Bank account or service,Checking account,Deposits and withdrawals,,NY,11102,Web,11/13/2014,11/13/2014,"FNIS (Fidelity National Information Services, Inc.)",In progress,Yes,
# 1115106,Debt collection,"Other (phone, health club, etc.)",Communication tactics,Frequent or repeated calls,GA,31721,Web,11/13/2014,11/13/2014,"Expert Global Solutions, Inc.",In progress,Yes,
#
# User-defined Counters
#
# Now, let’s use Hadoop Counters to identify the number of complaints pertaining to debt collection, mortgage and other categories (all other categories get lumped into this one) in the consumer complaints dataset. Basically produce the distribution of the Product column in this dataset using counters (limited to 3 counters here).
#
# Hadoop offers Job Tracker, an UI tool to determine the status and statistics of all jobs. Using the job tracker UI, developers can view the Counters that have been created. Screenshot your  job tracker UI as your job completes and include it here. Make sure that your user defined counters are visible.

# %% [markdown]
# # Explore data source file structure

# %%
with open('Consumer_Complaints.csv') as f:
    d = list(csv.reader(f))

print (d[0])
print(d[12])
# Out:
# ['Complaint ID', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'State', 'ZIP code', 'Submitted via', 'Date received', 'Date sent to company', 'Company', 'Company response', 'Timely response?', 'Consumer disputed?']
# ['1113072', 'Credit reporting', '', 'Incorrect information on credit report', 'Account status', 'NY', '11514', 'Web', '11/12/2014', '11/12/2014', 'TransUnion', 'Closed with explanation', 'Yes', '']

# %% [markdown]
# <h2> create folder</h2>

# %%
# !hdfs dfs -mkdir -p /user/venamax
# Out:
# 16/02/02 18:20:19 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# <h2>upload source file</h2>

# %%
# !hdfs dfs -put Consumer_Complaints.csv /user/venamax                 #### save source data file to hdfs  \
# !hdfs dfs -ls
# Out:
# 16/02/02 18:20:42 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/02 18:20:45 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 1 items
# -rw-r--r--   1 venamax supergroup   50906486 2016-02-02 18:20 Consumer_Complaints.csv

# %% [markdown]
# <h2>start/stop yarn  and hdfs</h2>

# %%
# !/usr/local/Cellar/hadoop/2.7.1/sbin/start-yarn.sh       ### start up yarn
# !/usr/local/Cellar/hadoop/2.7.1/sbin/start-dfs.sh        ### start up dfs
# Out:
# starting yarn daemons
# starting resourcemanager, logging to /usr/local/Cellar/hadoop/2.7.1/libexec/logs/yarn-venamax-resourcemanager-VENAMAX.local.out
# localhost: starting nodemanager, logging to /usr/local/Cellar/hadoop/2.7.1/libexec/logs/yarn-venamax-nodemanager-VENAMAX.local.out
# 16/02/02 20:53:37 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Starting namenodes on [localhost]
# localhost: starting namenode, logging to /usr/local/Cellar/hadoop/2.7.1/libexec/logs/hadoop-venamax-namenode-VENAMAX.local.out
# localhost: starting datanode, logging to /usr/local/Cellar/hadoop/2.7.1/libexec/logs/hadoop-venamax-datanode-VENAMAX.local.out
# Starting secondary namenodes [0.0.0.0]
# 0.0.0.0: starting secondarynamenode, logging to /usr/local/Cellar/hadoop/2.7.1/libexec/logs/hadoop-venamax-secondarynamenode-VENAMAX.local.out
# 16/02/02 20:53:56 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# !/usr/local/Cellar/hadoop/2.7.1/sbin/stop-yarn.sh
# !/usr/local/Cellar/hadoop/2.7.1/sbin/stop-dfs.sh
# Out:
# stopping yarn daemons
# stopping resourcemanager
# localhost: stopping nodemanager
# no proxyserver to stop
# 16/02/02 20:53:00 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Stopping namenodes on [localhost]
# localhost: stopping namenode
# localhost: stopping datanode
# Stopping secondary namenodes [0.0.0.0]
# 0.0.0.0: stopping secondarynamenode
# 16/02/02 20:53:21 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Mapper

# %%
# %%writefile mapper.py
#!/usr/bin/python
from csv import reader
import sys


for row in reader(iter(sys.stdin.readline, '')):
    product = row[1].lower()
    
    if product=='debt collection' or product == 'mortgage':
        product = product
    else:
        product = 'other'
    if product:
        sys.stderr.write("reporter:counter:complaints:,%s,1\n"%product)
    print ('%s\t%s' % (product, 1))             ### mapper out looks like 'product' \t 1
# Out:
# Overwriting mapper.py

# %%
# !chmod +x mapper.py

# %% [markdown]
# # Reducer

# %%
# %%writefile reducer.py
#!/usr/bin/python
from operator import itemgetter
import sys

current_product = None
current_count = 0
product = None
productlist = []
# input comes from STDIN
for line in sys.stdin:
    
    line = line.strip()                        ### remove leading and trailing whitespace
    line = line.split('\t')                    ### parse the input we got from mapper.py 
    product = line[0]                           ### integer generated randomly we got from mapper.py
    
    
    try:
        count = line[1]
        count = int(count)                      ### convert count (currently a string) to int

    except ValueError:                          ### if count was not a number then silently                         
        continue                                ### ignore/discard this line

                                                
                                                
    if current_product == product:                ### this IF-switch only works because Hadoop sorts map output
        current_count += count                  ### by key (here: number) before it is passed to the reducer
    else:
        if current_product:
            
            productlist.append((current_product,current_count))  ### store tuple in a list once totalize count per number

        current_count = count                   ### set current count
        current_product = product                 ### set current product


if current_product == product:                    ### do not forget to output the last word if needed!
    productlist.append((current_product,current_count))


toplist = sorted(productlist,key=lambda record: record[1], reverse=True) ### sort list from largest count to smallest

print '%25s' %'TOP Products'
print '%20s' %'Products', '%10s' %'Count'
for i in range(len(toplist)):
    print '%20s%10s' % (toplist[i][0], toplist[i][1])
# Out:
# Overwriting reducer.py

# %%
# !chmod +x reducer.py

# %% [markdown]
# # Run Consumer_Complaints in Hadoop

# %% [markdown]
# <h2> remove files from prior runs </h2>

# %%
# !hdfs dfs -rm -r /user/venamax/complaintsOutput                           ### remove prior files
# Out:
# 16/02/02 18:36:56 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/02 18:36:57 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted /user/venamax/complaintsOutput

# %% [markdown]
# <h2> Hadoop streaming command </h2>

# %% [markdown]
# hadoop jar hadoopstreamingjarfile \
#
#     -D stream.num.map.output.key.fields=n \
#     -mapper mapperfile \
#     -reducer reducerfile \
#     -input inputfile \
#     -output outputfile

# %%
# !hadoop jar hadoop-*streaming*.jar -mapper mapper.py -reducer reducer.py -input Consumer_Complaints.csv -output complaintsOutput
# Out:
# 16/02/02 18:37:06 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/02 18:37:08 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 16/02/02 18:37:08 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 16/02/02 18:37:08 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 16/02/02 18:37:08 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/02/02 18:37:08 INFO mapreduce.JobSubmitter: number of splits:1
# 16/02/02 18:37:08 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local736012362_0001
# 16/02/02 18:37:08 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 16/02/02 18:37:08 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 16/02/02 18:37:08 INFO mapreduce.Job: Running job: job_local736012362_0001
# 16/02/02 18:37:08 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 16/02/02 18:37:08 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/02 18:37:08 INFO mapred.LocalJobRunner: Waiting for map tasks
# 16/02/02 18:37:08 INFO mapred.LocalJobRunner: Starting task: attempt_local736012362_0001_m_000000_0
# 16/02/02 18:37:08 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/02 18:37:08 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/02 18:37:08 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/02 18:37:08 INFO mapred.MapTask: Processing split: hdfs://localhost:9000/user/venamax/Consumer_Complaints.csv:0+50906486
# 16/02/02 18:37:08 INFO mapred.MapTask: numReduceTasks: 1
# 16/02/02 18:37:08 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 16/02/02 18:37:08 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 16/02/02 18:37:08 INFO mapred.MapTask: soft limit at 83886080
# 16/02/02 18:37:08 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 16/02/02 18:37:08 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 16/02/02 18:37:08 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./mapper.py]
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 16/02/02 18:37:08 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 16/02/02 18:37:08 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 16/02/02 18:37:08 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 16/02/02 18:37:08 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 16/02/02 18:37:08 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:08 INFO streaming.PipeMapRed: Records R/W=2369/1
# 16/02/02 18:37:09 INFO streaming.PipeMapRed: R/W/S=10000/8671/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:09 INFO mapreduce.Job: Job job_local736012362_0001 running in uber mode : false
# 16/02/02 18:37:09 INFO mapreduce.Job:  map 0% reduce 0%
# 16/02/02 18:37:09 INFO streaming.PipeMapRed: R/W/S=100000/98977/0 in:100000=100000/1 [rec/s] out:98977=98977/1 [rec/s]
# 16/02/02 18:37:10 INFO streaming.PipeMapRed: R/W/S=200000/197176/0 in:100000=200000/2 [rec/s] out:98588=197176/2 [rec/s]
# 16/02/02 18:37:11 INFO streaming.PipeMapRed: R/W/S=300000/297855/0 in:150000=300000/2 [rec/s] out:148927=297855/2 [rec/s]
# 16/02/02 18:37:11 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/02 18:37:11 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/02 18:37:11 INFO mapred.LocalJobRunner:
# 16/02/02 18:37:11 INFO mapred.MapTask: Starting flush of map output
# 16/02/02 18:37:11 INFO mapred.MapTask: Spilling map output
# 16/02/02 18:37:11 INFO mapred.MapTask: bufstart = 0; bufend = 3324280; bufvoid = 104857600
# 16/02/02 18:37:11 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 24962748(99850992); length = 1251649/6553600
# 16/02/02 18:37:12 INFO mapred.MapTask: Finished spill 0
# 16/02/02 18:37:12 INFO mapred.Task: Task:attempt_local736012362_0001_m_000000_0 is done. And is in the process of committing
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: Records R/W=2369/1
# 16/02/02 18:37:12 INFO mapred.Task: Task 'attempt_local736012362_0001_m_000000_0' done.
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: Finishing task: attempt_local736012362_0001_m_000000_0
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: map task executor complete.
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: Starting task: attempt_local736012362_0001_r_000000_0
# 16/02/02 18:37:12 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/02 18:37:12 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/02 18:37:12 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/02 18:37:12 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@37d4166f
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/02 18:37:12 INFO reduce.EventFetcher: attempt_local736012362_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/02 18:37:12 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local736012362_0001_m_000000_0 decomp: 3950108 len: 3950112 to MEMORY
# 16/02/02 18:37:12 INFO reduce.InMemoryMapOutput: Read 3950108 bytes from map-output for attempt_local736012362_0001_m_000000_0
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3950108, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->3950108
# 16/02/02 18:37:12 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/02 18:37:12 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/02 18:37:12 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 3950090 bytes
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: Merged 1 segments, 3950108 bytes to disk to satisfy reduce memory limit
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: Merging 1 files, 3950112 bytes from disk
# 16/02/02 18:37:12 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/02 18:37:12 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/02 18:37:12 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 3950090 bytes
# 16/02/02 18:37:12 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/02 18:37:12 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/02 18:37:12 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:12 INFO mapreduce.Job:  map 100% reduce 0%
# 16/02/02 18:37:12 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:13 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/02 18:37:13 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/02 18:37:13 INFO streaming.PipeMapRed: Records R/W=312913/1
# 16/02/02 18:37:13 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/02 18:37:13 INFO mapred.Task: Task:attempt_local736012362_0001_r_000000_0 is done. And is in the process of committing
# 16/02/02 18:37:13 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/02 18:37:13 INFO mapred.Task: Task attempt_local736012362_0001_r_000000_0 is allowed to commit now
# 16/02/02 18:37:13 INFO output.FileOutputCommitter: Saved output of task 'attempt_local736012362_0001_r_000000_0' to hdfs://localhost:9000/user/venamax/complaintsOutput/_temporary/0/task_local736012362_0001_r_000000
# 16/02/02 18:37:13 INFO mapred.LocalJobRunner: Records R/W=312913/1 > reduce
# 16/02/02 18:37:13 INFO mapred.Task: Task 'attempt_local736012362_0001_r_000000_0' done.
# 16/02/02 18:37:13 INFO mapred.LocalJobRunner: Finishing task: attempt_local736012362_0001_r_000000_0
# 16/02/02 18:37:13 INFO mapred.LocalJobRunner: reduce task executor complete.
# 16/02/02 18:37:13 INFO mapreduce.Job:  map 100% reduce 100%
# 16/02/02 18:37:13 INFO mapreduce.Job: Job job_local736012362_0001 completed successfully
# 16/02/02 18:37:13 INFO mapreduce.Job: Counters: 39
# 	File System Counters
# 		FILE: Number of bytes read=8112076
# 		FILE: Number of bytes written=12647416
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=101812972
# 		HDFS: Number of bytes written=156
# 		HDFS: Number of read operations=13
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=312913
# 		Map output bytes=3324280
# 		Map output materialized bytes=3950112
# 		Input split bytes=110
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=3
# 		Reduce shuffle bytes=3950112
# 		Reduce input records=312913
# 		Reduce output records=5
# 		Spilled Records=625826
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=14
# 		Total committed heap usage (bytes)=636485632
# 	Mapper Counters
# 		Calls=1
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	complaints:
# 		debt collection=44372
# 		mortgage=125752
# 		other=142789
# 	File Input Format Counters
# 		Bytes Read=50906486
# 	File Output Format Counters
# 		Bytes Written=156
# 16/02/02 18:37:13 INFO streaming.StreamJob: Output directory: complaintsOutput

# %%
# !hdfs dfs -cat complaintsOutput/part-00000
# Out:
# 16/02/02 18:34:25 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#              TOP Products
#             Products      Count
#                other    142789
#             mortgage    125752
#      debt collection     44372

# %% [markdown]
# <h2>=====================
# END OF HW 3.1</h2>

# %% [markdown]
# <h2>HW 3.2 Analyze the performance of your Mappers, Combiners and Reducers using Counters</h2>
#
# For this brief study the Input file will be one record (the next line only):
# foo foo quux labs foo bar quux
#
#
# Perform a word count analysis of this single record dataset using a Mapper and Reducer based WordCount (i.e., no combiners are used here) using user defined Counters to count up how many time the mapper and reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing this word count job. The answer  should be 1 and 4 respectively. Please explain.
#
#
#
# Using a single reducer: What are the top 50 most frequent terms in your word count analysis? Present the top 50 terms and their frequency and their relative frequency. Present the top 50 terms and their frequency and their relative frequency. If there are ties please sort the tokens in alphanumeric/string order. Present bottom 10 tokens (least frequent items).

# %% [markdown]
# # Data

# %%
input_file = open("oneline.txt", "w") # writing file

terms = ['foo', 'foo',  'quux',  'labs',  'foo',  'bar',  'quux' ]
b = ' '

for term in terms:
    
    input_file.write(str(term))   
    input_file.write(b)  
    
    
    
    
input_file.write('\n')

   

input_file.close()

# %%
# !hdfs dfs -put oneline.txt /user/venamax                 #### save source data file to hdfs  \
# !hdfs dfs -ls
# Out:
# 16/02/02 20:54:31 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# put: `/user/venamax/oneline.txt': File exists
# 16/02/02 20:54:33 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 4 items
# -rw-r--r--   1 venamax supergroup   50906486 2016-02-02 18:20 Consumer_Complaints.csv
# drwxr-xr-x   - venamax supergroup          0 2016-02-02 18:37 complaintsOutput
# -rw-r--r--   1 venamax supergroup         32 2016-02-02 18:58 oneline.txt
# drwxr-xr-x   - venamax supergroup          0 2016-02-02 20:50 onelinecountOutput

# %% [markdown]
# # Mapper

# %%
# %%writefile wordcount/mapper.py
#!/usr/bin/python
import sys

sys.stderr.write("reporter:counter:Mapper Counter,Calls,1\n")

for line in sys.stdin:
    line = line.split()
    for word in line:
        print '%s\t%s' % (word,1)
# Out:
# Overwriting wordcount/mapper.py

# %%
# !chmod +x mapper.py

# %% [markdown]
# # Reducer

# %%
# %%writefile wordcount/reducer.py
#!/usr/bin/python
from operator import itemgetter
import sys

current_word = None
current_count = 0
word = None
words = {}

# input comes from STDIN


# input comes from STDIN
for line in sys.stdin:

    line = line.strip()                        ### remove leading and trailing whitespace
    line = line.split('\t')                    ### parse the input we got from mappe
    word = line[0]
    
    try:

        count = line[1]
        count = int(count)                      ### convert count (currently a string) to int
    except ValueError:                          ### if count was not a number then silently                         
        continue                                ### ignore/discard this line

                                                
                                                
    if current_word == word:                     ### this IF-switch only works because Hadoop sorts map output
        current_count += count                  ### by key (here: number) before it is passed to the reducer
    else:
        if current_word:
          
            words[current_word] = current_count  ### store tuple in a list once totalize count per number
  
        current_count = count                    ### set current count
        current_word = word                      ### set current word


if current_word == word:                         ### do not forget to output the last word if needed!
    words[current_word] = current_count 

for word in words:
    print 'We found "%s"' %word, ' on %s'%words[word] , 'occassions.'
    sys.stderr.write("reporter:counter:Reducer Counter,Calls,1\n")
# Out:
# Overwriting wordcount/reducer.py

# %% [markdown]
# # Run onelinecount in Hadoop

# %% [markdown]
# <h2> remove files from prior runs</h2>

# %%
# !hdfs dfs -rm -r /user/venamax/onelinecountOutput
# Out:
# 16/02/03 00:43:06 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/03 00:43:07 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted /user/venamax/onelinecountOutput

# %% [markdown]
# <h2> Hadoop streaming command </h2>

# %%
# !hadoop jar hadoop-*streaming*.jar -mapper wordcount/mapper.py -reducer wordcount/reducer.py -input oneline.txt -output onelinecountOutput
# Out:
# 16/02/03 00:43:12 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/03 00:43:12 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 16/02/03 00:43:12 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 16/02/03 00:43:12 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 16/02/03 00:43:13 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/02/03 00:43:13 INFO mapreduce.JobSubmitter: number of splits:1
# 16/02/03 00:43:13 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local136899566_0001
# 16/02/03 00:43:13 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 16/02/03 00:43:13 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 16/02/03 00:43:13 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 16/02/03 00:43:13 INFO mapreduce.Job: Running job: job_local136899566_0001
# 16/02/03 00:43:13 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 00:43:13 INFO mapred.LocalJobRunner: Waiting for map tasks
# 16/02/03 00:43:13 INFO mapred.LocalJobRunner: Starting task: attempt_local136899566_0001_m_000000_0
# 16/02/03 00:43:13 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 00:43:13 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 00:43:13 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 00:43:13 INFO mapred.MapTask: Processing split: hdfs://localhost:9000/user/venamax/oneline.txt:0+32
# 16/02/03 00:43:13 INFO mapred.MapTask: numReduceTasks: 1
# 16/02/03 00:43:13 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 16/02/03 00:43:13 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 16/02/03 00:43:13 INFO mapred.MapTask: soft limit at 83886080
# 16/02/03 00:43:13 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 16/02/03 00:43:13 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 16/02/03 00:43:13 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 16/02/03 00:43:13 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./wordcount/mapper.py]
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 16/02/03 00:43:13 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 16/02/03 00:43:13 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 16/02/03 00:43:13 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 16/02/03 00:43:13 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 16/02/03 00:43:13 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 16/02/03 00:43:13 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 00:43:14 INFO mapreduce.Job: Job job_local136899566_0001 running in uber mode : false
# 16/02/03 00:43:14 INFO mapreduce.Job:  map 0% reduce 0%
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: Records R/W=1/1
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner:
# 16/02/03 00:43:14 INFO mapred.MapTask: Starting flush of map output
# 16/02/03 00:43:14 INFO mapred.MapTask: Spilling map output
# 16/02/03 00:43:14 INFO mapred.MapTask: bufstart = 0; bufend = 45; bufvoid = 104857600
# 16/02/03 00:43:14 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214372(104857488); length = 25/6553600
# 16/02/03 00:43:14 INFO mapred.MapTask: Finished spill 0
# 16/02/03 00:43:14 INFO mapred.Task: Task:attempt_local136899566_0001_m_000000_0 is done. And is in the process of committing
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: Records R/W=1/1
# 16/02/03 00:43:14 INFO mapred.Task: Task 'attempt_local136899566_0001_m_000000_0' done.
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: Finishing task: attempt_local136899566_0001_m_000000_0
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: map task executor complete.
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: Starting task: attempt_local136899566_0001_r_000000_0
# 16/02/03 00:43:14 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 00:43:14 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 00:43:14 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 00:43:14 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@37326736
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 00:43:14 INFO reduce.EventFetcher: attempt_local136899566_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 00:43:14 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local136899566_0001_m_000000_0 decomp: 61 len: 65 to MEMORY
# 16/02/03 00:43:14 INFO reduce.InMemoryMapOutput: Read 61 bytes from map-output for attempt_local136899566_0001_m_000000_0
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 61, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->61
# 16/02/03 00:43:14 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 00:43:14 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 00:43:14 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 55 bytes
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: Merged 1 segments, 61 bytes to disk to satisfy reduce memory limit
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: Merging 1 files, 65 bytes from disk
# 16/02/03 00:43:14 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 00:43:14 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 00:43:14 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 55 bytes
# 16/02/03 00:43:14 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./wordcount/reducer.py]
# 16/02/03 00:43:14 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 00:43:14 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: Records R/W=7/1
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 00:43:14 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 00:43:15 INFO mapred.Task: Task:attempt_local136899566_0001_r_000000_0 is done. And is in the process of committing
# 16/02/03 00:43:15 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 00:43:15 INFO mapred.Task: Task attempt_local136899566_0001_r_000000_0 is allowed to commit now
# 16/02/03 00:43:15 INFO output.FileOutputCommitter: Saved output of task 'attempt_local136899566_0001_r_000000_0' to hdfs://localhost:9000/user/venamax/onelinecountOutput/_temporary/0/task_local136899566_0001_r_000000
# 16/02/03 00:43:15 INFO mapred.LocalJobRunner: Records R/W=7/1 > reduce
# 16/02/03 00:43:15 INFO mapred.Task: Task 'attempt_local136899566_0001_r_000000_0' done.
# 16/02/03 00:43:15 INFO mapred.LocalJobRunner: Finishing task: attempt_local136899566_0001_r_000000_0
# 16/02/03 00:43:15 INFO mapred.LocalJobRunner: reduce task executor complete.
# 16/02/03 00:43:15 INFO mapreduce.Job:  map 100% reduce 100%
# 16/02/03 00:43:15 INFO mapreduce.Job: Job job_local136899566_0001 completed successfully
# 16/02/03 00:43:15 INFO mapreduce.Job: Counters: 37
# 	File System Counters
# 		FILE: Number of bytes read=211942
# 		FILE: Number of bytes written=796923
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=64
# 		HDFS: Number of bytes written=138
# 		HDFS: Number of read operations=13
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=7
# 		Map output bytes=45
# 		Map output materialized bytes=65
# 		Input split bytes=98
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=4
# 		Reduce shuffle bytes=65
# 		Reduce input records=7
# 		Reduce output records=4
# 		Spilled Records=14
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=544210944
# 	Mapper Counter
# 		Calls=1
# 	Reducer Counter
# 		Calls=4
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=32
# 	File Output Format Counters
# 		Bytes Written=138
# 16/02/03 00:43:15 INFO streaming.StreamJob: Output directory: onelinecountOutput

# %%
# !hdfs dfs -cat onelinecountOutput/part-00000
# Out:
# 16/02/02 20:55:13 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# We found "labs"  on 1 occassions.
# We found "quux"  on 2 occassions.
# We found "foo"  on 3 occassions.
# We found "bar"  on 1 occassions.

# %% [markdown]
# <h2>HW 3.2 Part II</h2>
# Please use mulitple mappers and reducers for these jobs (at least 2 mappers and 2 reducers).
# Perform a word count analysis of the Issue column of the Consumer Complaints  Dataset using a Mapper and Reducer based WordCount (i.e., no combiners used anywhere)  using user defined Counters to count up how many time the mapper and reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing your word count job.

# %% [markdown]
# # Mapper

# %%
# %%writefile wordcount/mapper.py
#!/usr/bin/python
from csv import reader
import sys


for row in reader(iter(sys.stdin.readline, '')):
    product = row[1].lower()
    issue = row[3].lower()
    

    if product:
        bagofwords = issue.split(' ')
        for word in bagofwords:
            sys.stderr.write("reporter:counter:MapperCalls:,Calls,1\n")
            print ('%s\t%s' % (word, 1))             ### mapper out looks like 'word' \t 1
# Out:
# Overwriting wordcount/mapper.py

# %% [markdown]
# # Reducer

# %%
# %%writefile wordcount/reducer.py
#!/usr/bin/python
from operator import itemgetter
import sys

current_word = None
current_count = 0
word = None
initials = list(map(chr,range(97,123)))
words = {}

# input comes from STDIN


# input comes from STDIN
for line in sys.stdin:

    line = line.strip()                        ### remove leading and trailing whitespace
    line = line.split('\t')                    ### parse the input we got from mappe
    word = line[0]
    initial = str(word[0])
    
    if initial in initials:
        try:

            count = line[1]
            count = int(count)                      ### convert count (currently a string) to int
        except ValueError:                          ### if count was not a number then silently                         
            continue                                ### ignore/discard this line

                                                
                                                
        if current_word == word:                     ### this IF-switch only works because Hadoop sorts map output
            current_count += count                  ### by key (here: number) before it is passed to the reducer
        else:
            if current_word:
          
                words[current_word] = current_count  ### store tuple in a list once totalize count per number
  
            current_count = count                    ### set current count
            current_word = word                      ### set current word


if current_word == word:                         ### do not forget to output the last word if needed!
    words[current_word] = current_count 

topwords = sorted(words, key=words.__getitem__, reverse = True) ## sort 
for i in range (len(topwords)):
    word = topwords[i]
    print '"%s"' %word, '\t', '%s'%(words[word])
    sys.stderr.write("reporter:counter:ReducerCalls:,Calls,1\n")
# Out:
# Overwriting wordcount/reducer.py

# %% [markdown]
# # Run onelinecount in Hadoop

# %% [markdown]
# <h2> remove files from prior runs</h2>

# %%
# !hdfs dfs -rm -r /user/venamax/wordcountOutput
# Out:
# 16/02/03 14:50:58 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# rm: `/user/venamax/wordcountOutput': No such file or directory

# %% [markdown]
# <h2>Hadoop Streaming Command<h2>

# %%
# !hadoop jar hadoop-*streaming*.jar \
    -D mapred.map.tasks=2  \
    -mapper wordcount/mapper.py \
    -file wordcount/mapper.py \
    -reducer wordcount/reducer.py \
    -file wordcount/reducer.py \
    -input Consumer_Complaints.csv \
    -output wordcountOutput \
    -numReduceTasks 2
# Out:
# 16/02/03 14:51:01 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/02/03 14:51:01 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# packageJobJar: [wordcount/mapper.py, wordcount/reducer.py] [] /var/folders/53/mvqk9y495dncsjyk4kff13t40000gn/T/streamjob3580111230202414653.jar tmpDir=null
# 16/02/03 14:51:02 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 16/02/03 14:51:02 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 16/02/03 14:51:02 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 16/02/03 14:51:03 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/02/03 14:51:03 INFO mapreduce.JobSubmitter: number of splits:1
# 16/02/03 14:51:03 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 14:51:03 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local774562038_0001
# 16/02/03 14:51:03 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/mapper.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454521863584/mapper.py
# 16/02/03 14:51:03 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/reducer.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454521863585/reducer.py
# 16/02/03 14:51:03 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 16/02/03 14:51:03 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 16/02/03 14:51:03 INFO mapreduce.Job: Running job: job_local774562038_0001
# 16/02/03 14:51:03 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 16/02/03 14:51:03 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 14:51:03 INFO mapred.LocalJobRunner: Waiting for map tasks
# 16/02/03 14:51:03 INFO mapred.LocalJobRunner: Starting task: attempt_local774562038_0001_m_000000_0
# 16/02/03 14:51:03 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 14:51:03 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 14:51:03 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 14:51:03 INFO mapred.MapTask: Processing split: hdfs://localhost:9000/user/venamax/Consumer_Complaints.csv:0+50906486
# 16/02/03 14:51:03 INFO mapred.MapTask: numReduceTasks: 2
# 16/02/03 14:51:04 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 16/02/03 14:51:04 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 16/02/03 14:51:04 INFO mapred.MapTask: soft limit at 83886080
# 16/02/03 14:51:04 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 16/02/03 14:51:04 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 16/02/03 14:51:04 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./mapper.py]
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 16/02/03 14:51:04 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 16/02/03 14:51:04 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 16/02/03 14:51:04 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 16/02/03 14:51:04 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 16/02/03 14:51:04 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: Records R/W=1247/1
# 16/02/03 14:51:04 INFO streaming.PipeMapRed: R/W/S=10000/38525/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:04 INFO mapreduce.Job: Job job_local774562038_0001 running in uber mode : false
# 16/02/03 14:51:04 INFO mapreduce.Job:  map 0% reduce 0%
# 16/02/03 14:51:06 INFO streaming.PipeMapRed: R/W/S=100000/418284/0 in:50000=100000/2 [rec/s] out:209142=418284/2 [rec/s]
# 16/02/03 14:51:08 INFO streaming.PipeMapRed: R/W/S=200000/814351/0 in:50000=200000/4 [rec/s] out:203587=814351/4 [rec/s]
# 16/02/03 14:51:09 INFO mapred.LocalJobRunner: Records R/W=1247/1 > map
# 16/02/03 14:51:10 INFO streaming.PipeMapRed: R/W/S=300000/1160647/0 in:50000=300000/6 [rec/s] out:193441=1160647/6 [rec/s]
# 16/02/03 14:51:10 INFO mapreduce.Job:  map 56% reduce 0%
# 16/02/03 14:51:11 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 14:51:11 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 14:51:11 INFO mapred.LocalJobRunner: Records R/W=1247/1 > map
# 16/02/03 14:51:11 INFO mapred.MapTask: Starting flush of map output
# 16/02/03 14:51:11 INFO mapred.MapTask: Spilling map output
# 16/02/03 14:51:11 INFO mapred.MapTask: bufstart = 0; bufend = 13289355; bufvoid = 104857600
# 16/02/03 14:51:11 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 21394276(85577104); length = 4820121/6553600
# 16/02/03 14:51:12 INFO mapred.MapTask: Finished spill 0
# 16/02/03 14:51:12 INFO mapred.Task: Task:attempt_local774562038_0001_m_000000_0 is done. And is in the process of committing
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: Records R/W=1247/1
# 16/02/03 14:51:12 INFO mapred.Task: Task 'attempt_local774562038_0001_m_000000_0' done.
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: Finishing task: attempt_local774562038_0001_m_000000_0
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: map task executor complete.
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: Starting task: attempt_local774562038_0001_r_000000_0
# 16/02/03 14:51:12 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 14:51:12 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 14:51:12 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 14:51:12 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@7093a3eb
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 14:51:12 INFO reduce.EventFetcher: attempt_local774562038_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 14:51:12 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local774562038_0001_m_000000_0 decomp: 9479513 len: 9479517 to MEMORY
# 16/02/03 14:51:12 INFO reduce.InMemoryMapOutput: Read 9479513 bytes from map-output for attempt_local774562038_0001_m_000000_0
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 9479513, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->9479513
# 16/02/03 14:51:12 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 14:51:12 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 14:51:12 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 9479509 bytes
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: Merged 1 segments, 9479513 bytes to disk to satisfy reduce memory limit
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: Merging 1 files, 9479517 bytes from disk
# 16/02/03 14:51:12 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 14:51:12 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 14:51:12 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 9479509 bytes
# 16/02/03 14:51:12 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/03 14:51:12 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 14:51:12 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:12 INFO mapreduce.Job:  map 100% reduce 0%
# 16/02/03 14:51:12 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:13 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:13 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:13 INFO streaming.PipeMapRed: R/W/S=400000/0/0 in:400000=400000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 14:51:13 INFO streaming.PipeMapRed: R/W/S=500000/0/0 in:500000=500000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=600000/0/0 in:600000=600000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: Records R/W=687439/1
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 14:51:14 INFO mapred.Task: Task:attempt_local774562038_0001_r_000000_0 is done. And is in the process of committing
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:14 INFO mapred.Task: Task attempt_local774562038_0001_r_000000_0 is allowed to commit now
# 16/02/03 14:51:14 INFO output.FileOutputCommitter: Saved output of task 'attempt_local774562038_0001_r_000000_0' to hdfs://localhost:9000/user/venamax/wordcountOutput/_temporary/0/task_local774562038_0001_r_000000
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: Records R/W=687439/1 > reduce
# 16/02/03 14:51:14 INFO mapred.Task: Task 'attempt_local774562038_0001_r_000000_0' done.
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: Finishing task: attempt_local774562038_0001_r_000000_0
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: Starting task: attempt_local774562038_0001_r_000001_0
# 16/02/03 14:51:14 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 14:51:14 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 14:51:14 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 14:51:14 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@11474bd9
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 14:51:14 INFO reduce.EventFetcher: attempt_local774562038_0001_r_000001_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 14:51:14 INFO reduce.LocalFetcher: localfetcher#2 about to shuffle output of map attempt_local774562038_0001_m_000000_0 decomp: 6219908 len: 6219912 to MEMORY
# 16/02/03 14:51:14 INFO reduce.InMemoryMapOutput: Read 6219908 bytes from map-output for attempt_local774562038_0001_m_000000_0
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 6219908, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->6219908
# 16/02/03 14:51:14 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 14:51:14 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 14:51:14 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 6219905 bytes
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: Merged 1 segments, 6219908 bytes to disk to satisfy reduce memory limit
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: Merging 1 files, 6219912 bytes from disk
# 16/02/03 14:51:14 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 14:51:14 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 14:51:14 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 6219905 bytes
# 16/02/03 14:51:14 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/03 14:51:14 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:14 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:14 INFO mapreduce.Job:  map 100% reduce 50%
# 16/02/03 14:51:15 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:15 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:15 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 14:51:15 INFO streaming.PipeMapRed: R/W/S=400000/0/0 in:400000=400000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 14:51:16 INFO streaming.PipeMapRed: R/W/S=500000/0/0 in:500000=500000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 14:51:16 INFO streaming.PipeMapRed: Records R/W=517592/1
# 16/02/03 14:51:16 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 14:51:16 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 14:51:16 INFO mapred.Task: Task:attempt_local774562038_0001_r_000001_0 is done. And is in the process of committing
# 16/02/03 14:51:16 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 14:51:16 INFO mapred.Task: Task attempt_local774562038_0001_r_000001_0 is allowed to commit now
# 16/02/03 14:51:16 INFO output.FileOutputCommitter: Saved output of task 'attempt_local774562038_0001_r_000001_0' to hdfs://localhost:9000/user/venamax/wordcountOutput/_temporary/0/task_local774562038_0001_r_000001
# 16/02/03 14:51:16 INFO mapred.LocalJobRunner: Records R/W=517592/1 > reduce
# 16/02/03 14:51:16 INFO mapred.Task: Task 'attempt_local774562038_0001_r_000001_0' done.
# 16/02/03 14:51:16 INFO mapred.LocalJobRunner: Finishing task: attempt_local774562038_0001_r_000001_0
# 16/02/03 14:51:16 INFO mapred.LocalJobRunner: reduce task executor complete.
# 16/02/03 14:51:16 INFO mapreduce.Job:  map 100% reduce 100%
# 16/02/03 14:51:16 INFO mapreduce.Job: Job job_local774562038_0001 completed successfully
# 16/02/03 14:51:16 INFO mapreduce.Job: Counters: 37
# 	File System Counters
# 		FILE: Number of bytes read=50377278
# 		FILE: Number of bytes written=73171929
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=152719458
# 		HDFS: Number of bytes written=4047
# 		HDFS: Number of read operations=24
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=9
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1205031
# 		Map output bytes=13289355
# 		Map output materialized bytes=15699429
# 		Input split bytes=110
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=175
# 		Reduce shuffle bytes=15699429
# 		Reduce input records=1205031
# 		Reduce output records=173
# 		Spilled Records=2410062
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=1000341504
# 	MapperCalls:
# 		Calls=1205031
# 	ReducerCalls:
# 		Calls=173
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50906486
# 	File Output Format Counters
# 		Bytes Written=2758
# 16/02/03 14:51:16 INFO streaming.StreamJob: Output directory: wordcountOutput

# %%
# !hdfs dfs -cat wordcountOutput/part-00000
# Out:
# 16/02/03 14:51:19 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# "modification,collection,foreclosure" 	70487
# "account" 	57448
# "credit" 	50894
# "or" 	40508
# "payments," 	39993
# "escrow" 	36767
# "incorrect" 	29069
# "on" 	29069
# "debt" 	27874
# "not" 	18477
# "owed" 	17972
# "cont'd" 	17972
# "and" 	16448
# "closing," 	16205
# "management" 	16205
# "of" 	13983
# "deposits" 	10555
# "tactics" 	8671
# "broker" 	8625
# "to" 	8401
# "unable" 	8178
# "billing" 	8158
# "disclosure" 	7655
# "verification" 	7655
# "disputes" 	6938
# "the" 	6248
# "caused" 	5663
# "being" 	5663
# "by" 	5663
# "process" 	5505
# "company's" 	4858
# "settlement" 	4350
# "protection" 	4139
# "your" 	3844
# "repaying" 	3844
# "you" 	3821
# "false" 	3621
# "representation" 	3621
# "a" 	3503
# "apr" 	3431
# "theft" 	3276
# "an" 	2964
# "can't" 	1999
# "servicer" 	1944
# "repay" 	1647
# "service" 	1518
# "determination" 	1490
# "use" 	1477
# "relations" 	1367
# "statement" 	1220
# "payoff" 	1155
# "increase/decrease" 	1149
# "issue" 	1099
# "delinquent" 	1061
# "for" 	929
# "i" 	925
# "expect" 	807
# "fees" 	807
# "unsolicited" 	640
# "issuance" 	640
# "transfer" 	597
# "terms" 	350
# "workout" 	350
# "changes" 	350
# "was" 	274
# "available" 	274
# "promised" 	274
# "delay" 	243
# "processing" 	243
# "cash" 	240
# "bankruptcy" 	222
# "received" 	216
# "wrong" 	169
# "arbitration" 	168
# "acct" 	163
# "receive" 	139
# "sale" 	139
# "applied" 	139
# "charges" 	131
# "overlimit" 	127
# "checks" 	75
# "convenience" 	75

# %%
# !hdfs dfs -cat wordcountOutput/part-00001
# Out:
# 16/02/03 14:51:26 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# "loan" 	119491
# "servicing," 	36767
# "report" 	30546
# "information" 	29069
# "attempts" 	17972
# "collect" 	17972
# "opening," 	16205
# "my" 	10731
# "withdrawals" 	10555
# "problems" 	9484
# "communication" 	8671
# "mortgage" 	8625
# "originator," 	8625
# "application," 	8625
# "other" 	7886
# "reporting" 	6559
# "lease" 	6337
# "low" 	5663
# "funds" 	5663
# "managing" 	5006
# "improper" 	4966
# "investigation" 	4858
# "identity" 	4729
# "card" 	4405
# "get" 	4357
# "score" 	4357
# "report/credit" 	4357
# "costs" 	4350
# "interest" 	4238
# "when" 	4095
# "fraud" 	3842
# "are" 	3821
# "pay" 	3821
# "contact" 	3710
# "money" 	3639
# "statements" 	3621
# "info" 	3553
# "sharing" 	3489
# "rate" 	3431
# "embezzlement" 	3276
# "making/receiving" 	3226
# "sending" 	3226
# "fee" 	3198
# "taking/threatening" 	2964
# "action" 	2964
# "illegal" 	2964
# "closing/cancelling" 	2795
# "underwriting" 	2774
# "decision" 	2774
# "customer" 	2734
# "using" 	2422
# "debit" 	2422
# "atm" 	2422
# "lender" 	2165
# "dealing" 	1944
# "with" 	1944
# "collection" 	1907
# "late" 	1797
# "line" 	1732
# "transaction" 	1485
# "monitoring" 	1453
# "out" 	1242
# "taking" 	1242
# "marketing" 	1193
# "advertising" 	1193
# "practices" 	1003
# "rewards" 	1002
# "charged" 	976
# "didn't" 	925
# "dispute" 	904
# "shopping" 	672
# "balance" 	597
# "scam" 	566
# "issues" 	538
# "forbearance" 	350
# "plans" 	350
# "getting" 	291
# "application" 	243
# "privacy" 	240
# "advance" 	240
# "bank" 	202
# "loan/did" 	139
# "stop" 	131
# "apply" 	118
# "amount" 	98
# "credited" 	92
# "payment" 	92
# "amt" 	71
# "day" 	71
# "incorrect/missing" 	64
# "disclosures" 	64

# %% [markdown]
# <h2>HW 3.2 Part III</h2>
# Perform a word count analysis of the Issue column of the Consumer Complaints  Dataset using a Mapper, Reducer, and standalone combiner (i.e., not an in-memory combiner) based WordCount using user defined Counters to count up how many time the mapper, combiner, reducer are called. What is the value of your user defined Mapper Counter, and Reducer Counter after completing your word count job.

# %% [markdown]
# # Combiner

# %%
# %%writefile wordcount/combiner.py
#!/usr/bin/python
from operator import itemgetter
import sys

current_word = None
current_count = 0
word = None
words = {}

# input comes from STDIN


# input comes from STDIN
for line in sys.stdin:
    line = line.strip()                        ### remove leading and trailing whitespace
    line = line.split('\t')                    ### parse the input we got from mappe
    if len(line) == 2:
        
        word = line[0]
    

        try:

            count = line[1]
            count = int(count)                      ### convert count (currently a string) to int
        except ValueError:                          ### if count was not a number then silently                         
            continue                                ### ignore/discard this line

                                                
                                                
        if current_word == word:                     ### this IF-switch only works because Hadoop sorts map output
            current_count += count                  ### by key (here: number) before it is passed to the reducer
        else:
            if current_word:
          
                words[current_word] = current_count  ### store tuple in a list once totalize count per number
  
            current_count = count                    ### set current count
            current_word = word                      ### set current word


if current_word == word:                         ### do not forget to output the last word if needed!
    words[current_word] = current_count 

for word in words:
        sys.stderr.write("reporter:counter:CombinerCalls:,Calls,1\n")
        print ('%s\t%s' % (word, words[word]))             ### mapper out looks like 'word' \t local sum'
# Out:
# Overwriting wordcount/combiner.py

# %% [markdown]
# # Run onelinecount in Hadoop

# %% [markdown]
# <h2> remove files from prior runs</h2>

# %%
# !hdfs dfs -rm -r /user/venamax/wordcountOutput
# Out:
# 16/02/03 15:56:32 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/03 15:56:33 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted /user/venamax/wordcountOutput

# %% [markdown]
# <h2>Hadoop Streaming Command<h2>

# %%
# !hadoop jar hadoop-*streaming*.jar \
    -D mapred.map.tasks=2  \
    -mapper wordcount/mapper.py \
    -file wordcount/mapper.py \
    -combiner wordcount/combiner.py \
    -file wordcount/combiner.py \
    -reducer wordcount/reducer.py \
    -file wordcount/reducer.py \
    -input Consumer_Complaints.csv \
    -output wordcountOutput \
    -numReduceTasks 2
# Out:
# 16/02/03 15:56:40 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/02/03 15:56:41 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# packageJobJar: [wordcount/mapper.py, wordcount/combiner.py, wordcount/reducer.py] [] /var/folders/53/mvqk9y495dncsjyk4kff13t40000gn/T/streamjob6545775260055764349.jar tmpDir=null
# 16/02/03 15:56:41 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 16/02/03 15:56:41 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 16/02/03 15:56:41 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 16/02/03 15:56:41 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/02/03 15:56:42 INFO mapreduce.JobSubmitter: number of splits:1
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 15:56:42 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local997349634_0001
# 16/02/03 15:56:42 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/mapper.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454525802254/mapper.py
# 16/02/03 15:56:42 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/combiner.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454525802255/combiner.py
# 16/02/03 15:56:42 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/reducer.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454525802256/reducer.py
# 16/02/03 15:56:42 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 16/02/03 15:56:42 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 16/02/03 15:56:42 INFO mapreduce.Job: Running job: job_local997349634_0001
# 16/02/03 15:56:42 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 16/02/03 15:56:42 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 15:56:42 INFO mapred.LocalJobRunner: Waiting for map tasks
# 16/02/03 15:56:42 INFO mapred.LocalJobRunner: Starting task: attempt_local997349634_0001_m_000000_0
# 16/02/03 15:56:42 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 15:56:42 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 15:56:42 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 15:56:42 INFO mapred.MapTask: Processing split: hdfs://localhost:9000/user/venamax/Consumer_Complaints.csv:0+50906486
# 16/02/03 15:56:42 INFO mapred.MapTask: numReduceTasks: 2
# 16/02/03 15:56:42 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 16/02/03 15:56:42 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 16/02/03 15:56:42 INFO mapred.MapTask: soft limit at 83886080
# 16/02/03 15:56:42 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 16/02/03 15:56:42 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 16/02/03 15:56:42 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./mapper.py]
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 16/02/03 15:56:42 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 16/02/03 15:56:42 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 16/02/03 15:56:42 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 16/02/03 15:56:42 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 16/02/03 15:56:42 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: Records R/W=1188/1
# 16/02/03 15:56:42 INFO streaming.PipeMapRed: R/W/S=10000/38703/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:43 INFO mapreduce.Job: Job job_local997349634_0001 running in uber mode : false
# 16/02/03 15:56:43 INFO mapreduce.Job:  map 0% reduce 0%
# 16/02/03 15:56:45 INFO streaming.PipeMapRed: R/W/S=100000/418284/0 in:50000=100000/2 [rec/s] out:209142=418284/2 [rec/s]
# 16/02/03 15:56:47 INFO streaming.PipeMapRed: R/W/S=200000/814351/0 in:50000=200000/4 [rec/s] out:203587=814351/4 [rec/s]
# 16/02/03 15:56:48 INFO mapred.LocalJobRunner: Records R/W=1188/1 > map
# 16/02/03 15:56:49 INFO streaming.PipeMapRed: R/W/S=300000/1160647/0 in:50000=300000/6 [rec/s] out:193441=1160647/6 [rec/s]
# 16/02/03 15:56:49 INFO mapreduce.Job:  map 56% reduce 0%
# 16/02/03 15:56:49 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 15:56:49 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 15:56:49 INFO mapred.LocalJobRunner: Records R/W=1188/1 > map
# 16/02/03 15:56:49 INFO mapred.MapTask: Starting flush of map output
# 16/02/03 15:56:49 INFO mapred.MapTask: Spilling map output
# 16/02/03 15:56:49 INFO mapred.MapTask: bufstart = 0; bufend = 13289355; bufvoid = 104857600
# 16/02/03 15:56:49 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 21394276(85577104); length = 4820121/6553600
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./combiner.py]
# 16/02/03 15:56:50 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:50 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=400000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=500000/0/0 in:500000=500000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 15:56:51 INFO mapred.LocalJobRunner: Records R/W=1188/1 > sort
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=600000/0/0 in:600000=600000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: Records R/W=687439/1
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./combiner.py]
# 16/02/03 15:56:51 INFO Configuration.deprecation: mapred.skip.reduce.auto.incr.proc.count is deprecated. Instead, use mapreduce.reduce.skip.proc-count.auto-incr
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:51 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:52 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:52 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:52 INFO mapreduce.Job:  map 67% reduce 0%
# 16/02/03 15:56:52 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:52 INFO streaming.PipeMapRed: R/W/S=400000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: R/W/S=500000/0/0 in:500000=500000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: Records R/W=517592/1
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 15:56:53 INFO mapred.MapTask: Finished spill 0
# 16/02/03 15:56:53 INFO mapred.Task: Task:attempt_local997349634_0001_m_000000_0 is done. And is in the process of committing
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Records R/W=517592/1
# 16/02/03 15:56:53 INFO mapred.Task: Task 'attempt_local997349634_0001_m_000000_0' done.
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Finishing task: attempt_local997349634_0001_m_000000_0
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: map task executor complete.
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Starting task: attempt_local997349634_0001_r_000000_0
# 16/02/03 15:56:53 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 15:56:53 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 15:56:53 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 15:56:53 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@5a67108d
# 16/02/03 15:56:53 INFO mapreduce.Job:  map 100% reduce 0%
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 15:56:53 INFO reduce.EventFetcher: attempt_local997349634_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 15:56:53 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local997349634_0001_m_000000_0 decomp: 1219 len: 1223 to MEMORY
# 16/02/03 15:56:53 INFO reduce.InMemoryMapOutput: Read 1219 bytes from map-output for attempt_local997349634_0001_m_000000_0
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1219, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->1219
# 16/02/03 15:56:53 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 15:56:53 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 15:56:53 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1213 bytes
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merged 1 segments, 1219 bytes to disk to satisfy reduce memory limit
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merging 1 files, 1223 bytes from disk
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 15:56:53 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 15:56:53 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1213 bytes
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/03 15:56:53 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 15:56:53 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: Records R/W=83/1
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 15:56:53 INFO mapred.Task: Task:attempt_local997349634_0001_r_000000_0 is done. And is in the process of committing
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO mapred.Task: Task attempt_local997349634_0001_r_000000_0 is allowed to commit now
# 16/02/03 15:56:53 INFO output.FileOutputCommitter: Saved output of task 'attempt_local997349634_0001_r_000000_0' to hdfs://localhost:9000/user/venamax/wordcountOutput/_temporary/0/task_local997349634_0001_r_000000
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Records R/W=83/1 > reduce
# 16/02/03 15:56:53 INFO mapred.Task: Task 'attempt_local997349634_0001_r_000000_0' done.
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Finishing task: attempt_local997349634_0001_r_000000_0
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Starting task: attempt_local997349634_0001_r_000001_0
# 16/02/03 15:56:53 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 15:56:53 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 15:56:53 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 15:56:53 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@605d1b0b
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 15:56:53 INFO reduce.EventFetcher: attempt_local997349634_0001_r_000001_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 15:56:53 INFO reduce.LocalFetcher: localfetcher#2 about to shuffle output of map attempt_local997349634_0001_m_000000_0 decomp: 1380 len: 1384 to MEMORY
# 16/02/03 15:56:53 INFO reduce.InMemoryMapOutput: Read 1380 bytes from map-output for attempt_local997349634_0001_m_000000_0
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1380, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->1380
# 16/02/03 15:56:53 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 15:56:53 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 15:56:53 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1372 bytes
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merged 1 segments, 1380 bytes to disk to satisfy reduce memory limit
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merging 1 files, 1384 bytes from disk
# 16/02/03 15:56:53 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 15:56:53 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 15:56:53 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1372 bytes
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/03 15:56:53 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: Records R/W=91/1
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 15:56:53 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 15:56:53 INFO mapred.Task: Task:attempt_local997349634_0001_r_000001_0 is done. And is in the process of committing
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 15:56:53 INFO mapred.Task: Task attempt_local997349634_0001_r_000001_0 is allowed to commit now
# 16/02/03 15:56:53 INFO output.FileOutputCommitter: Saved output of task 'attempt_local997349634_0001_r_000001_0' to hdfs://localhost:9000/user/venamax/wordcountOutput/_temporary/0/task_local997349634_0001_r_000001
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Records R/W=91/1 > reduce
# 16/02/03 15:56:53 INFO mapred.Task: Task 'attempt_local997349634_0001_r_000001_0' done.
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: Finishing task: attempt_local997349634_0001_r_000001_0
# 16/02/03 15:56:53 INFO mapred.LocalJobRunner: reduce task executor complete.
# 16/02/03 15:56:54 INFO mapreduce.Job:  map 100% reduce 100%
# 16/02/03 15:56:54 INFO mapreduce.Job: Job job_local997349634_0001 completed successfully
# 16/02/03 15:56:54 INFO mapreduce.Job: Counters: 38
# 	File System Counters
# 		FILE: Number of bytes read=29259
# 		FILE: Number of bytes written=917564
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=152719458
# 		HDFS: Number of bytes written=4047
# 		HDFS: Number of read operations=24
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=9
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1205031
# 		Map output bytes=13289355
# 		Map output materialized bytes=2607
# 		Input split bytes=110
# 		Combine input records=1205031
# 		Combine output records=174
# 		Reduce input groups=174
# 		Reduce shuffle bytes=2607
# 		Reduce input records=174
# 		Reduce output records=173
# 		Spilled Records=348
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=22
# 		Total committed heap usage (bytes)=1003487232
# 	CombinerCalls:
# 		Calls=174
# 	MapperCalls:
# 		Calls=1205031
# 	ReducerCalls:
# 		Calls=173
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50906486
# 	File Output Format Counters
# 		Bytes Written=2758
# 16/02/03 15:56:54 INFO streaming.StreamJob: Output directory: wordcountOutput

# %% [markdown]
# <h2>H3.2 Part IV</h2>
# Using a single reducer: What are the top 50 most frequent terms in your word count analysis? Present the top 50 terms and their frequency and their relative frequency. Present the top 50 terms and their frequency and their relative frequency. If there are ties please sort the tokens in alphanumeric/string order. Present bottom 10 tokens (least frequent items).

# %% [markdown]
# # Mapper

# %%
# %%writefile wordcount/mapper.py
#!/usr/bin/python
from csv import reader
import sys
sum_total = 0

for row in reader(iter(sys.stdin.readline, '')):
    product = row[1].lower()
    issue = row[3].lower()
    

    if product:
        bagofwords = issue.split(' ')
        for word in bagofwords:
            sum_total += 1
            sys.stderr.write("reporter:counter:MapperCalls:,Calls,1\n")
            print ('%s\t%s' % (word, 1))             ### mapper out looks like 'word' \t 1

print ('%s\t%s' % ('*', sum_total))             ### total sum to calculate frequencies
sys.stderr.write("reporter:counter:MapperCalls:,%s,1\n"%'*')
# Out:
# Overwriting wordcount/mapper.py

# %% [markdown]
# # Reducer

# %%
# %%writefile wordcount/reducer.py
#!/usr/bin/python
from operator import itemgetter
import sys

current_word = None
current_count = 0
word = None
initials = list(map(chr,range(97,123)))
wordcounts = {}
wordfrequencies = {}
sum_total=0

# input comes from STDIN


# input comes from STDIN
for line in sys.stdin:

    line = line.strip()                        ### remove leading and trailing whitespace
    line = line.split('\t')                    ### parse the input we got from mappe
    word = line[0]

    if line[0] == '*':
        sum_total += int(line[1])
    
    else:
    
        initial = str(word[0])
    
        if initial in initials:
            try:

                count = line[1]
                count = int(count)                      ### convert count (currently a string) to int
                if count > 100000:
                    sys.stderr.write("reporter:counter:CombinerCalls:,%s,1\n"%word)
                                         

            except ValueError:                          ### if count was not a number then silently                         
                continue                                ### ignore/discard this line

                                                
                                                
            if current_word == word:                     ### this IF-switch only works because Hadoop sorts map output
                current_count += count*1.0                  ### by key (here: number) before it is passed to the reducer
            else:
                if current_word:
          
                    wordcounts[current_word] = current_count
                    wordfrequencies[current_word] = current_count/sum_total
                current_count = count                    ### set current count
                current_word = word                      ### set current word


if current_word == word:                         ### do not forget to output the last word if needed!
    wordcounts[current_word] = current_count
    wordfrequencies[current_word]= current_count/sum_total

topwords = sorted(wordfrequencies, key=wordfrequencies.__getitem__, reverse = True) ## sort 
for i in range (len(topwords)):
    word = topwords[i]
    print '"%s"\t%s\t%s'%(word,wordcounts[word],wordfrequencies[word])
    sys.stderr.write("reporter:counter:ReducerCalls:,Calls,1\n")
# Out:
# Overwriting wordcount/reducer.py

# %% [markdown]
# # Run onelinecount in Hadoop

# %% [markdown]
# <h2> remove files from prior runs</h2>

# %%
# !hdfs dfs -rm -r /user/venamax/wordcountOutput
# Out:
# 16/02/04 12:01:00 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 16/02/04 12:01:01 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 0 minutes, Emptier interval = 0 minutes.
# Deleted /user/venamax/wordcountOutput

# %% [markdown]
# <h2>Hadoop Streaming Command<h2>

# %%
# !hadoop jar hadoop-*streaming*.jar \
    -D mapred.map.tasks=2  \
    -mapper wordcount/mapper.py \
    -file wordcount/mapper.py \
    -reducer wordcount/reducer.py \
    -file wordcount/reducer.py \
    -input Consumer_Complaints.csv \
    -output wordcountOutput \
    -numReduceTasks 1
##   -combiner wordcount/combiner.py \
##    -file wordcount/combiner.py \
# Out:
# 16/02/03 23:50:07 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 16/02/03 23:50:07 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# packageJobJar: [wordcount/mapper.py, wordcount/reducer.py] [] /var/folders/53/mvqk9y495dncsjyk4kff13t40000gn/T/streamjob3762375606845144423.jar tmpDir=null
# 16/02/03 23:50:08 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 16/02/03 23:50:08 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 16/02/03 23:50:08 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 16/02/03 23:50:09 INFO mapred.FileInputFormat: Total input paths to process : 1
# 16/02/03 23:50:09 INFO mapreduce.JobSubmitter: number of splits:1
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 23:50:09 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local436634629_0001
# 16/02/03 23:50:09 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/mapper.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454554209398/mapper.py
# 16/02/03 23:50:09 INFO mapred.LocalDistributedCacheManager: Localized file:/Users/venamax/ucb-261/hw3/wordcount/reducer.py as file:/usr/local/Cellar/hadoop/hdfs/tmp/mapred/local/1454554209399/reducer.py
# 16/02/03 23:50:09 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 16/02/03 23:50:09 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 16/02/03 23:50:09 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 16/02/03 23:50:09 INFO mapreduce.Job: Running job: job_local436634629_0001
# 16/02/03 23:50:09 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 23:50:09 INFO mapred.LocalJobRunner: Waiting for map tasks
# 16/02/03 23:50:09 INFO mapred.LocalJobRunner: Starting task: attempt_local436634629_0001_m_000000_0
# 16/02/03 23:50:09 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 23:50:09 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 23:50:09 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 23:50:09 INFO mapred.MapTask: Processing split: hdfs://localhost:9000/user/venamax/Consumer_Complaints.csv:0+50906486
# 16/02/03 23:50:09 INFO mapred.MapTask: numReduceTasks: 1
# 16/02/03 23:50:09 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 16/02/03 23:50:09 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 16/02/03 23:50:09 INFO mapred.MapTask: soft limit at 83886080
# 16/02/03 23:50:09 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 16/02/03 23:50:09 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 16/02/03 23:50:09 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./mapper.py]
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 16/02/03 23:50:09 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 16/02/03 23:50:09 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 16/02/03 23:50:09 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 16/02/03 23:50:09 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 16/02/03 23:50:09 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:09 INFO streaming.PipeMapRed: Records R/W=1248/1
# 16/02/03 23:50:10 INFO streaming.PipeMapRed: R/W/S=10000/38704/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:10 INFO mapreduce.Job: Job job_local436634629_0001 running in uber mode : false
# 16/02/03 23:50:10 INFO mapreduce.Job:  map 0% reduce 0%
# 16/02/03 23:50:12 INFO streaming.PipeMapRed: R/W/S=100000/418284/0 in:50000=100000/2 [rec/s] out:209142=418284/2 [rec/s]
# 16/02/03 23:50:14 INFO streaming.PipeMapRed: R/W/S=200000/814351/0 in:50000=200000/4 [rec/s] out:203587=814351/4 [rec/s]
# 16/02/03 23:50:15 INFO mapred.LocalJobRunner: Records R/W=1248/1 > map
# 16/02/03 23:50:16 INFO streaming.PipeMapRed: R/W/S=300000/1160647/0 in:50000=300000/6 [rec/s] out:193441=1160647/6 [rec/s]
# 16/02/03 23:50:16 INFO mapreduce.Job:  map 55% reduce 0%
# 16/02/03 23:50:16 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 23:50:16 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 23:50:16 INFO mapred.LocalJobRunner: Records R/W=1248/1 > map
# 16/02/03 23:50:16 INFO mapred.MapTask: Starting flush of map output
# 16/02/03 23:50:16 INFO mapred.MapTask: Spilling map output
# 16/02/03 23:50:16 INFO mapred.MapTask: bufstart = 0; bufend = 13289365; bufvoid = 104857600
# 16/02/03 23:50:16 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 21394272(85577088); length = 4820125/6553600
# 16/02/03 23:50:17 INFO mapred.MapTask: Finished spill 0
# 16/02/03 23:50:17 INFO mapred.Task: Task:attempt_local436634629_0001_m_000000_0 is done. And is in the process of committing
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: Records R/W=1248/1
# 16/02/03 23:50:17 INFO mapred.Task: Task 'attempt_local436634629_0001_m_000000_0' done.
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: Finishing task: attempt_local436634629_0001_m_000000_0
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: map task executor complete.
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: Starting task: attempt_local436634629_0001_r_000000_0
# 16/02/03 23:50:17 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 16/02/03 23:50:17 INFO util.ProcfsBasedProcessTree: ProcfsBasedProcessTree currently is supported only on Linux.
# 16/02/03 23:50:17 INFO mapred.Task:  Using ResourceCalculatorProcessTree : null
# 16/02/03 23:50:17 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@632aa7e0
# 16/02/03 23:50:17 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=334338464, maxSingleShuffleLimit=83584616, mergeThreshold=220663392, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 16/02/03 23:50:17 INFO reduce.EventFetcher: attempt_local436634629_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 16/02/03 23:50:17 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local436634629_0001_m_000000_0 decomp: 15699431 len: 15699435 to MEMORY
# 16/02/03 23:50:17 INFO reduce.InMemoryMapOutput: Read 15699431 bytes from map-output for attempt_local436634629_0001_m_000000_0
# 16/02/03 23:50:17 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 15699431, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->15699431
# 16/02/03 23:50:17 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 16/02/03 23:50:17 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 23:50:17 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 16/02/03 23:50:17 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 23:50:17 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 15699428 bytes
# 16/02/03 23:50:18 INFO reduce.MergeManagerImpl: Merged 1 segments, 15699431 bytes to disk to satisfy reduce memory limit
# 16/02/03 23:50:18 INFO reduce.MergeManagerImpl: Merging 1 files, 15699435 bytes from disk
# 16/02/03 23:50:18 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 16/02/03 23:50:18 INFO mapred.Merger: Merging 1 sorted segments
# 16/02/03 23:50:18 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 15699428 bytes
# 16/02/03 23:50:18 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: PipeMapRed exec [/Users/venamax/ucb-261/hw3/./reducer.py]
# 16/02/03 23:50:18 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 16/02/03 23:50:18 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:18 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:18 INFO mapreduce.Job:  map 100% reduce 0%
# 16/02/03 23:50:19 INFO streaming.PipeMapRed: R/W/S=100000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:19 INFO streaming.PipeMapRed: R/W/S=200000/0/0 in:NA [rec/s] out:NA [rec/s]
# 16/02/03 23:50:19 INFO streaming.PipeMapRed: R/W/S=300000/0/0 in:300000=300000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 23:50:19 INFO streaming.PipeMapRed: R/W/S=400000/0/0 in:400000=400000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 23:50:20 INFO streaming.PipeMapRed: R/W/S=500000/0/0 in:500000=500000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 23:50:20 INFO streaming.PipeMapRed: R/W/S=600000/0/0 in:600000=600000/1 [rec/s] out:0=0/1 [rec/s]
# 16/02/03 23:50:20 INFO streaming.PipeMapRed: R/W/S=700000/0/0 in:350000=700000/2 [rec/s] out:0=0/2 [rec/s]
# 16/02/03 23:50:20 INFO streaming.PipeMapRed: R/W/S=800000/0/0 in:400000=800000/2 [rec/s] out:0=0/2 [rec/s]
# 16/02/03 23:50:21 INFO streaming.PipeMapRed: R/W/S=900000/0/0 in:450000=900000/2 [rec/s] out:0=0/2 [rec/s]
# 16/02/03 23:50:21 INFO streaming.PipeMapRed: R/W/S=1000000/0/0 in:333333=1000000/3 [rec/s] out:0=0/3 [rec/s]
# 16/02/03 23:50:21 INFO streaming.PipeMapRed: R/W/S=1100000/0/0 in:366666=1100000/3 [rec/s] out:0=0/3 [rec/s]
# 16/02/03 23:50:22 INFO streaming.PipeMapRed: R/W/S=1200000/0/0 in:400000=1200000/3 [rec/s] out:0=0/3 [rec/s]
# 16/02/03 23:50:22 INFO streaming.PipeMapRed: Records R/W=1205032/1
# 16/02/03 23:50:22 INFO streaming.PipeMapRed: MRErrorThread done
# 16/02/03 23:50:22 INFO streaming.PipeMapRed: mapRedFinished
# 16/02/03 23:50:22 INFO mapred.Task: Task:attempt_local436634629_0001_r_000000_0 is done. And is in the process of committing
# 16/02/03 23:50:22 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 16/02/03 23:50:22 INFO mapred.Task: Task attempt_local436634629_0001_r_000000_0 is allowed to commit now
# 16/02/03 23:50:22 INFO output.FileOutputCommitter: Saved output of task 'attempt_local436634629_0001_r_000000_0' to hdfs://localhost:9000/user/venamax/wordcountOutput/_temporary/0/task_local436634629_0001_r_000000
# 16/02/03 23:50:22 INFO mapred.LocalJobRunner: Records R/W=1205032/1 > reduce
# 16/02/03 23:50:22 INFO mapred.Task: Task 'attempt_local436634629_0001_r_000000_0' done.
# 16/02/03 23:50:22 INFO mapred.LocalJobRunner: Finishing task: attempt_local436634629_0001_r_000000_0
# 16/02/03 23:50:22 INFO mapred.LocalJobRunner: reduce task executor complete.
# 16/02/03 23:50:23 INFO mapreduce.Job:  map 100% reduce 100%
# 16/02/03 23:50:23 INFO mapreduce.Job: Job job_local436634629_0001 completed successfully
# 16/02/03 23:50:23 INFO mapreduce.Job: Counters: 38
# 	File System Counters
# 		FILE: Number of bytes read=31407856
# 		FILE: Number of bytes written=47696319
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=101812972
# 		HDFS: Number of bytes written=5893
# 		HDFS: Number of read operations=13
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Map-Reduce Framework
# 		Map input records=312913
# 		Map output records=1205032
# 		Map output bytes=13289365
# 		Map output materialized bytes=15699435
# 		Input split bytes=110
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=176
# 		Reduce shuffle bytes=15699435
# 		Reduce input records=1205032
# 		Reduce output records=173
# 		Spilled Records=2410064
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=22
# 		Total committed heap usage (bytes)=668991488
# 	MapperCalls:
# 		*=1
# 		Calls=1205031
# 	ReducerCalls:
# 		Calls=173
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=50906486
# 	File Output Format Counters
# 		Bytes Written=5893
# 16/02/03 23:50:23 INFO streaming.StreamJob: Output directory: wordcountOutput

# %%
# !hdfs dfs -cat wordcountOutput/part-00000
# Out:
# 16/02/03 23:50:45 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# "loan"	119491.0	0.0991601045948
# "modification,collection,foreclosure"	70487.0	0.0584939308615
# "account"	57448.0	0.0476734623425
# "credit"	50894.0	0.0422345981141
# "or"	40508.0	0.0336157327073
# "payments,"	39993.0	0.0331883578099
# "servicing,"	36767.0	0.0305112482583
# "escrow"	36767.0	0.0305112482583
# "report"	30546.0	0.0253487254685
# "on"	29069.0	0.0241230308598
# "incorrect"	29069.0	0.0241230308598
# "information"	29069.0	0.0241230308598
# "debt"	27874.0	0.023131355127
# "not"	18477.0	0.015333215494
# "attempts"	17972.0	0.0149141391383
# "collect"	17972.0	0.0149141391383
# "owed"	17972.0	0.0149141391383
# "cont'd"	17972.0	0.0149141391383
# "and"	16448.0	0.0136494413837
# "opening,"	16205.0	0.0134477868204
# "closing,"	16205.0	0.0134477868204
# "management"	16205.0	0.0134477868204
# "of"	13983.0	0.0116038508553
# "my"	10731.0	0.00890516509534
# "deposits"	10555.0	0.00875911076147
# "withdrawals"	10555.0	0.00875911076147
# "problems"	9484.0	0.00787033694569
# "communication"	8671.0	0.0071956655057
# "tactics"	8671.0	0.0071956655057
# "broker"	8625.0	0.00715749221389
# "originator,"	8625.0	0.00715749221389
# "application,"	8625.0	0.00715749221389
# "mortgage"	8625.0	0.00715749221389
# "to"	8401.0	0.00697160487987
# "unable"	8178.0	0.00678654740003
# "billing"	8158.0	0.00676995031663
# "other"	7886.0	0.00654422998247
# "verification"	7655.0	0.00635253366926
# "disclosure"	7655.0	0.00635253366926
# "disputes"	6938.0	0.00575752822956
# "reporting"	6559.0	0.00544301349924
# "lease"	6337.0	0.00525878587356
# "the"	6248.0	0.00518492885245
# "being"	5663.0	0.00469946416316
# "caused"	5663.0	0.00469946416316
# "by"	5663.0	0.00469946416316
# "low"	5663.0	0.00469946416316
# "funds"	5663.0	0.00469946416316
# "process"	5505.0	0.00456834720435
# "managing"	5006.0	0.00415424997365
# "improper"	4966.0	0.00412105580686
# "investigation"	4858.0	0.00403143155653
# "company's"	4858.0	0.00403143155653
# "identity"	4729.0	0.00392438036864
# "card"	4405.0	0.00365550761765
# "get"	4357.0	0.0036156746175
# "report/credit"	4357.0	0.0036156746175
# "score"	4357.0	0.0036156746175
# "settlement"	4350.0	0.00360986563831
# "costs"	4350.0	0.00360986563831
# "interest"	4238.0	0.0035169219713
# "protection"	4139.0	0.0034347664085
# "when"	4095.0	0.00339825282503
# "your"	3844.0	0.00318995942843
# "repaying"	3844.0	0.00318995942843
# "fraud"	3842.0	0.00318829972009
# "are"	3821.0	0.00317087278253
# "pay"	3821.0	0.00317087278253
# "you"	3821.0	0.00317087278253
# "contact"	3710.0	0.00307875896969
# "money"	3639.0	0.00301983932364
# "representation"	3621.0	0.00300490194858
# "statements"	3621.0	0.00300490194858
# "false"	3621.0	0.00300490194858
# "info"	3553.0	0.00294847186504
# "a"	3503.0	0.00290697915655
# "sharing"	3489.0	0.00289536119818
# "apr"	3431.0	0.00284722965633
# "rate"	3431.0	0.00284722965633
# "embezzlement"	3276.0	0.00271860226002
# "theft"	3276.0	0.00271860226002
# "making/receiving"	3226.0	0.00267710955154
# "sending"	3226.0	0.00267710955154
# "fee"	3198.0	0.00265387363479
# "taking/threatening"	2964.0	0.00245968775907
# "action"	2964.0	0.00245968775907
# "illegal"	2964.0	0.00245968775907
# "an"	2964.0	0.00245968775907
# "closing/cancelling"	2795.0	0.00231944240439
# "underwriting"	2774.0	0.00230201546682
# "decision"	2774.0	0.00230201546682
# "customer"	2734.0	0.00226882130003
# "using"	2422.0	0.00200990679908
# "debit"	2422.0	0.00200990679908
# "atm"	2422.0	0.00200990679908
# "lender"	2165.0	0.00179663427746
# "can't"	1999.0	0.00165887848528
# "dealing"	1944.0	0.00161323650595
# "with"	1944.0	0.00161323650595
# "servicer"	1944.0	0.00161323650595
# "collection"	1907.0	0.00158253190167
# "late"	1797.0	0.001491247943
# "line"	1732.0	0.00143730742197
# "repay"	1647.0	0.00136676981754
# "service"	1518.0	0.00125971862965
# "determination"	1490.0	0.00123648271289
# "transaction"	1485.0	0.00123233344204
# "use"	1477.0	0.00122569460869
# "monitoring"	1453.0	0.00120577810861
# "relations"	1367.0	0.00113441065002
# "out"	1242.0	0.0010306788788
# "taking"	1242.0	0.0010306788788
# "statement"	1220.0	0.00101242208707
# "marketing"	1193.0	0.000990016024484
# "advertising"	1193.0	0.000990016024484
# "payoff"	1155.0	0.000958481566034
# "increase/decrease"	1149.0	0.000953502441016
# "issue"	1099.0	0.00091200973253
# "delinquent"	1061.0	0.00088047527408
# "practices"	1003.0	0.000832343732236
# "rewards"	1002.0	0.000831513878066
# "charged"	976.0	0.000809937669653
# "for"	929.0	0.000770934523676
# "i"	925.0	0.000767615106997
# "didn't"	925.0	0.000767615106997
# "dispute"	904.0	0.000750188169433
# "fees"	807.0	0.000669692314969
# "expect"	807.0	0.000669692314969
# "shopping"	672.0	0.000557662002056
# "unsolicited"	640.0	0.000531106668625
# "issuance"	640.0	0.000531106668625
# "transfer"	597.0	0.000495422939327
# "balance"	597.0	0.000495422939327
# "scam"	566.0	0.000469697460065
# "issues"	538.0	0.000446461543313
# "workout"	350.0	0.000290448959404
# "forbearance"	350.0	0.000290448959404
# "terms"	350.0	0.000290448959404
# "changes"	350.0	0.000290448959404
# "plans"	350.0	0.000290448959404
# "getting"	291.0	0.00024148756339
# "available"	274.0	0.000227380042505
# "was"	274.0	0.000227380042505
# "promised"	274.0	0.000227380042505
# "processing"	243.0	0.000201654563244
# "delay"	243.0	0.000201654563244
# "application"	243.0	0.000201654563244
# "advance"	240.0	0.000199165000734
# "privacy"	240.0	0.000199165000734
# "cash"	240.0	0.000199165000734
# "bankruptcy"	222.0	0.000184227625679
# "received"	216.0	0.000179248500661
# "bank"	202.0	0.000167630542285
# "wrong"	169.0	0.000140245354684
# "arbitration"	168.0	0.000139415500514
# "acct"	163.0	0.000135266229665
# "applied"	139.0	0.000115349729592
# "receive"	139.0	0.000115349729592
# "loan/did"	139.0	0.000115349729592
# "sale"	139.0	0.000115349729592
# "stop"	131.0	0.000108710896234
# "charges"	131.0	0.000108710896234
# "overlimit"	127.0	0.000105391479555
# "apply"	118.0	9.79227920278e-05
# "amount"	98.0	8.13257086332e-05
# "credited"	92.0	7.63465836149e-05
# "payment"	92.0	7.63465836149e-05
# "convenience"	75.0	6.22390627295e-05
# "checks"	75.0	6.22390627295e-05
# "amt"	71.0	5.89196460506e-05
# "day"	71.0	5.89196460506e-05
# "incorrect/missing"	64.0	5.31106668625e-05
# "disclosures"	64.0	5.31106668625e-05

# %% [markdown]
# <h2>3.2.1 OPTIONAL
# Using 2 reducers: What are the top 50 most frequent terms in your word count analysis? Present the top 50 terms and their frequency and their relative frequency. Present the top 50 terms and their frequency and their relative frequency. If there are ties please sort the tokens in alphanumeric/string order. Present bottom 10 tokens (least frequent items). </h2>

# %% [markdown]
# <h2>HW3.3. Shopping Cart Analysis</h2>
# Product Recommendations: The action or practice of selling additional products or services
# to existing customers is called cross-selling. Giving product recommendation is
# one of the examples of cross-selling that are frequently used by online retailers.
# One simple method to give product recommendations is to recommend products that are frequently
# browsed together by the customers.
#
# For this homework use the online browsing behavior dataset located at:
#
#        https://www.dropbox.com/s/zlfyiwa70poqg74/ProductPurchaseData.txt?dl=0
#
# Each line in this dataset represents a browsing session of a customer.
# On each line, each string of 8 characters represents the id of an item browsed during that session.
# The items are separated by spaces.
#
# Here are the first few lines of the ProductPurchaseData
# FRO11987 ELE17451 ELE89019 SNA90258 GRO99222
# GRO99222 GRO12298 FRO12685 ELE91550 SNA11465 ELE26917 ELE52966 FRO90334 SNA30755 ELE17451 FRO84225 SNA80192
# ELE17451 GRO73461 DAI22896 SNA99873 FRO86643
# ELE17451 ELE37798 FRO86643 GRO56989 ELE23393 SNA11465
# ELE17451 SNA69641 FRO86643 FRO78087 SNA11465 GRO39357 ELE28573 ELE11375 DAI54444
#
#
# Do some exploratory data analysis of this dataset.
#
# How many unique items are available from this supplier?
#
# Using a single reducer: Report your findings such as number of unique products; largest basket; report the top 50 most frequently purchased items,  their frequency,  and their relative frequency (break ties by sorting the products alphabetical order) etc. using Hadoop Map-Reduce.

# %% [markdown]
# <h2>HW3.4. (Computationally prohibitive but then again Hadoop can handle this) Pairs</h2>
#
# Suppose we want to recommend new products to the customer based on the products they
# have already browsed on the online website. Write a map-reduce program
# to find products which are frequently browsed together. Fix the support count (cooccurence count) to s = 100
# (i.e. product pairs need to occur together at least 100 times to be considered frequent)
# and find pairs of items (sometimes referred to itemsets of size 2 in association rule mining) that have a support count of 100 or more.
#
# List the top 50 product pairs with corresponding support count (aka frequency), and relative frequency or support (number of records where they coccur, the number of records where they coccur/the number of baskets in the dataset)  in decreasing order of support  for frequent (100>count) itemsets of size 2.
#
# Use the Pairs pattern (lecture 3)  to  extract these frequent itemsets of size 2. Free free to use combiners if they bring value. Instrument your code with counters for count the number of times your mapper, combiner and reducers are called.
#
# Please output records of the following form for the top 50 pairs (itemsets of size 2):
#
#       item1, item2, support count, support
#
#
#
# Fix the ordering of the pairs lexicographically (left to right),
# and break ties in support (between pairs, if any exist)
# by taking the first ones in lexicographically increasing order.
#
# Report  the compute time for the Pairs job. Describe the computational setup used (E.g., single computer; dual core; linux, number of mappers, number of reducers)
# Instrument your mapper, combiner, and reducer to count how many times each is called using Counters and report these counts.

# %% [markdown]
# <h2> HW3.5: Stripes
# Repeat 3.4 using the stripes design pattern for finding cooccuring pairs.</h2>
#
# Report  the compute times for stripes job versus the Pairs job. Describe the computational setup used (E.g., single computer; dual core; linux, number of mappers, number of reducers)
#
# Instrument your mapper, combiner, and reducer to count how many times each is called using Counters and report these counts. Discuss the differences in these counts between the Pairs and Stripes jobs

# %% [markdown]
# OPTIONAL: all HW below this are optional
#
# NOTE:   -- as of 1/28/2016 the instructions needs to be completed (Talk to Jimi)
#
#
#
# == Preliminary information ===
#
# Much of this homework beyond this point will focus on the Apriori algorithm for frequent itemset  mining and the additional step for extracting association rules from these frequent itemsets.
# Please acquaint yourself with the background information (below)
# before approaching the remaining  assignments.
#
# === Apriori background information ===
#
# Some background material for the  Apriori algorithm is located at:
#
#  - Slides in Live Session #3
#  - https://en.wikipedia.org/wiki/Apriori_algorithm
#  - https://www.dropbox.com/s/k2zm4otych279z2/Apriori-good-slides.pdf?dl=0
#  - http://snap.stanford.edu/class/cs246-2014/slides/02-assocrules.pdf
#
# Association Rules are frequently used for Market Basket Analysis (MBA) by retailers to
# understand the purchase behavior of their customers. This information can be then used for
# many different purposes such as cross-selling and up-selling of products, sales promotions,
# loyalty programs, store design, discount plans and many others.
# Evaluation of item sets: Once you have found the frequent itemsets of a dataset, you need
# to choose a subset of them as your recommendations. Commonly used metrics for measuring
# significance and interest for selecting rules for recommendations are: confidence; lift; and conviction.
#
# <h2>HW3.6
# What is the Apriori algorithm? Describe an example use in your domain of expertise and what kind of . Define confidence and lift.</h2>
#
# NOTE:
# For the remaining homework use the online browsing behavior dataset located at (same dataset as used above):
#
#        https://www.dropbox.com/s/zlfyiwa70poqg74/ProductPurchaseData.txt?dl=0
#
# Each line in this dataset represents a browsing session of a customer.
# On each line, each string of 8 characters represents the id of an item browsed during that session.
# The items are separated by spaces.
#
# Here are the first few lines of the ProductPurchaseData
# FRO11987 ELE17451 ELE89019 SNA90258 GRO99222
# GRO99222 GRO12298 FRO12685 ELE91550 SNA11465 ELE26917 ELE52966 FRO90334 SNA30755 ELE17451 FRO84225 SNA80192
# ELE17451 GRO73461 DAI22896 SNA99873 FRO86643
# ELE17451 ELE37798 FRO86643 GRO56989 ELE23393 SNA11465
# ELE17451 SNA69641 FRO86643 FRO78087 SNA11465 GRO39357 ELE28573 ELE11375 DAI54444

# %% [markdown]
# <h2> HW3.7. Shopping Cart Analysis </h2>
# Product Recommendations: The action or practice of selling additional products or services
# to existing customers is called cross-selling. Giving product recommendation is
# one of the examples of cross-selling that are frequently used by online retailers.
# One simple method to give product recommendations is to recommend products that are frequently
# browsed together by the customers.
#
# Suppose we want to recommend new products to the customer based on the products they
# have already browsed on the online website. Write a program using the A-priori algorithm
# to find products which are frequently browsed together. Fix the support to s = 100
# (i.e. product sets need to occur together at least 100 times to be considered frequent)
# and find itemsets of size 2 and 3.
#
# Then extract association rules from these frequent items.
#
# A rule is of the form:
#
# (item1, item5) ⇒ item2.
#
# List the top 10 discovered rules in descreasing order of confidence in the following format
#
# (item1, item5) ⇒ item2, supportCount ,support, confidence

# %% [markdown]
# <h2> HW3.8
#
# Benchmark your results using the pyFIM implementation of the Apriori algorithm
# (Apriori - Association Rule Induction / Frequent Item Set Mining implemented by Christian Borgelt).
# You can download pyFIM from here: </h2>
#
# http://www.borgelt.net/pyfim.html
#
# Comment on the results from both implementations (your Hadoop MapReduce of apriori versus pyFIM)
# in terms of results and execution times.
#
#
# HW3.8 (Conceptual Exercise)
#
# Suppose that you wished to perform the Apriori algorithm once again,
# though this time now with the goal of listing the top 5 rules with corresponding confidence scores
# in decreasing order of confidence score for itemsets of size 3 using Hadoop MapReduce.
# A rule is now of the form:
#
# (item1, item2) ⇒ item3
#
# Recall that the Apriori algorithm is iterative for increasing itemset size,
# working off of the frequent itemsets of the previous size to explore
# ONLY the NECESSARY subset of a large combinatorial space.
# Describe how you might design a framework to perform this exercise.
#
# In particular, focus on the following:
#   — map-reduce steps required
#   - enumeration of item sets and filtering for frequent candidates
